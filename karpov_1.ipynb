# %%
my_name = 'Ludok'
my_age = 31
like_Python = True

# %%
print(my_name)
# Out:
# Ludok

# %%
if like_Python == True:
    print(my_name, my_age)
# Out:
# Ludok 31

# %%
a = 2
b = 3
c = (a**2 + b**2)**0.5
print(c)
# Out:
# 3.605551275463989

# %%
father_age = 40.0
son_age = 15.0
result = son_age*2 - father_age
if result < 0:
    result = -1*result
print(result, father_age + result, son_age+ result)
# Out:
# 10.0 50.0 25.0

# %%
a = 3
b = 4
c = 5

perimeter = (a + b + c)
p = perimeter/2
area = (p*(p-a)*(p-b)*(p-c))**0.5
print(p, area)
# Out:
# 6.0 6.0

# %%
n = 23810

a = n//60
hours = 0
if a > 1:
    hours = a//60  
minutes = (n - hours*60*60)//60
seconds = n%60

print('a = ', a,', time =', hours,':', minutes,':', seconds)
# Out:
# a =  396 , time = 6 : 36 : 50

# %%
price_new = 89.99 
price_old = 75.50
result = round(abs(price_new - price_old)/price_old*100,2)
print(result)
# Out:
# 19.19

# %%
a = 5
b = '10'
c = True
my_sum = int(b) + int(c)
print(my_sum)
# Out:
# 11

# %%
a = '0.56'
c = int(float(a))
print(c)
# Out:
# 0

# %%
x = 2
y = int(str(x)+str(0)+str(x)+str(0)+str(x))
result = x + y
print(result)
# Out:
# 20204

# %%
m = 500
optimal_sleep_duration = False
if (m//60 >= 7) and (m//60 <= 9):
    optimal_sleep_duration = True
print(optimal_sleep_duration)
# Out:
# True

# %%
x = 21
result = False

if (x%3 == 0)  and (x%7 == 0):
    result = True
print(result)
# Out:
# True

# %%
True+0
# Out:
# 1

# %%
string1 = '\'Манчестер Юнайтед\' - чемпион Англии!\n2013'
print(string1)
# Out:
# 'Манчестер Юнайтед' - чемпион Англии!
# 2013

# %%
square = '* * * *\n* * * *\n* * * *\n* * * *'
print( square)
# Out:
# * * * *
# * * * *
# * * * *
# * * * *
